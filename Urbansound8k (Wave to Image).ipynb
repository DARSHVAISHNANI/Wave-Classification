# %%
import os
import pandas as pd
import numpy as np
import librosa

# Path to the UrbanSound8K dataset
dataset_path = 'C:\\Users\\darsh\\Deep_Learning\\UrbanSound8K\\audio'
metadata_path = os.path.join(dataset_path, 'C:\\Users\\darsh\\Deep_Learning\\UrbanSound8K\\metadata\\UrbanSound8K.csv')

# Load metadata
metadata = pd.read_csv(metadata_path)

# Function to load audio file and convert to waveform
def load_audio_file(file_path):
    waveform, sample_rate = librosa.load(file_path, sr=None)
    return waveform, sample_rate

# Directory to save waveforms
waveform_dir = 'path_to_save_waveforms'
os.makedirs(waveform_dir, exist_ok=True)

# Process each audio file in the dataset
waveform_data = []

for index, row in metadata.iterrows():
    fold = row['fold']
    file_name = row['slice_file_name']
    file_path = os.path.join(dataset_path, f'fold{fold}', file_name)
    
    # Load audio file and convert to waveform
    waveform, sample_rate = load_audio_file(file_path)
    
    # Save waveform and metadata
    waveform_info = {
        'file_name': file_name,
        'waveform': waveform,
        'sample_rate': sample_rate,
        'class': row['class']
    }
    waveform_data.append(waveform_info)
    
    # Optional: Save waveform to a file for later use
    np.save(os.path.join(waveform_dir, file_name.replace('.wav', '.npy')), waveform)

# Convert the waveform data list to a DataFrame for easier manipulation
waveform_df = pd.DataFrame(waveform_data)

# Save the waveform DataFrame to a CSV file
waveform_df.to_csv(os.path.join(waveform_dir, 'waveform_data.csv'), index=False)

print("Waveform dataset creation completed.")
# Out:
# Waveform dataset creation completed.

# %%
import os
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import tensorflow as tf

with tf.device('/GPU:0'):
    # Path to the UrbanSound8K dataset and the metadata file
    dataset_path = 'C:\\Users\\darsh\\Deep_Learning\\Datset_of_csv'
    metadata_path = os.path.join(dataset_path, 'C:\\Users\\darsh\\Deep_Learning\\UrbanSound8K\\metadata\\UrbanSound8K.csv')
    
    # Load metadata
    metadata = pd.read_csv(metadata_path)
    
    # Function to load audio file and convert to mel spectrogram
    def save_mel_spectrogram(file_path, save_path):
        y, sr = librosa.load(file_path, sr=None)
        S = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=128)
        S_DB = librosa.power_to_db(S, ref=np.max)
        
        plt.figure(figsize=(10, 4))
        librosa.display.specshow(S_DB, sr=sr, x_axis='time', y_axis='mel')
        plt.colorbar(format='%+2.0f dB')
        plt.title('Mel Spectrogram')
        plt.tight_layout()
        plt.savefig(save_path, bbox_inches='tight', pad_inches=0)
        plt.close()
    
    # Directory to save mel spectrogram images
    mel_spectrogram_dir = 'C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class'
    os.makedirs(mel_spectrogram_dir, exist_ok=True)
    
    # Save mel spectrogram of the single audio file
    save_path = os.path.join(mel_spectrogram_dir, file_name.replace('.wav', '.png'))
    save_mel_spectrogram(file_path, save_path)
    
    # Save metadata for the single file
    mel_spectrogram_info = {
        'file_name': file_name,
        'mel_spectrogram_path': save_path,
        'class': single_file_metadata['class']
    }
    
    # Optionally, save the metadata for the single file to a CSV for reference
    single_mel_spectrogram_df = pd.DataFrame([mel_spectrogram_info])
    single_mel_spectrogram_df.to_csv(os.path.join(mel_spectrogram_dir, 'single_mel_spectrogram_data.csv'), index=False)
    
    print("Processed mel spectrogram information:")
    print(f"File name: {mel_spectrogram_info['file_name']}")
    print(f"Mel spectrogram saved at: {mel_spectrogram_info['mel_spectrogram_path']}")
    print(f"Class: {mel_spectrogram_info['class']}")
# Out:
# C:\Users\darsh\AppData\Local\Temp\ipykernel_16976\2209546677.py:19: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file_path, sr=None)
# C:\Users\darsh\miniconda3\envs\tf\lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# ---------------------------------------------------------------------------
# LibsndfileError                           Traceback (most recent call last)
# File ~\miniconda3\envs\tf\lib\site-packages\librosa\core\audio.py:176, in load(path, sr, mono, offset, duration, dtype, res_type)
#     175 try:
# --> 176     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     178 except sf.SoundFileRuntimeError as exc:
#     179     # If soundfile failed, try audioread instead
#
# ...

# %%
with tf.device('/GPU:0'):
    # Directory to save mel spectrogram images
    mel_spectrogram_dir = 'C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class'
    os.makedirs(mel_spectrogram_dir, exist_ok=True)
    
    # Process each audio file in the dataset
    mel_spectrogram_data = []
    
    for index, row in metadata.iterrows():
        fold = row['fold']
        file_name = row['slice_file_name']
        file_path = os.path.join(dataset_path, f'fold{fold}', file_name)
        
        # Save mel spectrogram of the audio file
        save_path = os.path.join(mel_spectrogram_dir, file_name.replace('.wav', '.png'))
        save_mel_spectrogram(file_path, save_path)
        
        # Save metadata
        mel_spectrogram_info = {
            'file_name': file_name,
            'mel_spectrogram_path': save_path,
            'class': row['class']
        }
        mel_spectrogram_data.append(mel_spectrogram_info)
    
    # Convert the mel spectrogram data list to a DataFrame for easier manipulation
with tf.device('/GPU:0'): 
    mel_spectrogram_df = pd.DataFrame(mel_spectrogram_data)
    
    # Save the mel spectrogram DataFrame to a CSV file
    mel_spectrogram_df.to_csv(os.path.join(mel_spectrogram_dir, 'mel_spectrogram_data.csv'), index=False)
    
    print("Mel spectrogram dataset creation completed.")
# Out:
# C:\Users\darsh\miniconda3\envs\tf\lib\site-packages\librosa\feature\spectral.py:2143: UserWarning: Empty filters detected in mel frequency basis. Some channels will produce empty responses. Try increasing your sampling rate (and fmax) or reducing n_mels.
#   mel_basis = filters.mel(sr=sr, n_fft=n_fft, **kwargs)
# Mel spectrogram dataset creation completed.

# %%
import os
import shutil
import pandas as pd

# Define the path to the UrbanSound8K dataset
dataset_path = 'C:/Users/darsh/Deep_Learning/UrbanSound8K'
metadata_path = os.path.join(dataset_path, 'C:/Users/darsh/Deep_Learning/UrbanSound8K/metadata/UrbanSound8K.csv')
audio_folder = os.path.join(dataset_path, 'C:/Users/darsh/Deep_Learning/UrbanSound8K/audio')

# Load the metadata
metadata = pd.read_csv(metadata_path)

# Define the target directory for sorted files
sorted_dir = 'C:/Users/darsh/Deep_Learning/Datset_of_csv'
os.makedirs(sorted_dir, exist_ok=True)

# Create class directories
classes = metadata['class'].unique()
for class_name in classes:
    class_dir = os.path.join(sorted_dir, class_name)
    os.makedirs(class_dir, exist_ok=True)

# Move files into corresponding class directories
for index, row in metadata.iterrows():
    file_path = os.path.join(audio_folder, 'fold' + str(row['fold']), row['slice_file_name'])
    target_dir = os.path.join(sorted_dir, row['class'])
    shutil.move(file_path, target_dir)

print("Files sorted into class directories successfully.")
# Out:
# Files sorted into class directories successfully.

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def create_spectrogram(wav_file, output_path):
    y, sr = librosa.load(wav_file)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    S_dB = librosa.power_to_db(S, ref=np.max)
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_dB, sr=sr)
    plt.colorbar(format='%+2.0f dB')
    # plt.title('Mel-frequency spectrogram')
    plt.tight_layout()
    
    plt.savefig(output_path)
    plt.close()

def process_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for subdir, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.wav'):
                class_name = os.path.basename(subdir)
                output_subfolder = os.path.join(output_folder, class_name)
                if not os.path.exists(output_subfolder):
                    os.makedirs(output_subfolder)
                
                wav_file = os.path.join(subdir, file)
                output_path = os.path.join(output_subfolder, os.path.splitext(file)[0] + '.png')
                create_spectrogram(wav_file, output_path)
                print(f"Processed {wav_file} to {output_path}")

input_folder = "C:\\Users\\darsh\\Deep_Learning\\Datset_of_csv\\dog_bark"
output_folder = "C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class\\dog_bark"
process_folder(input_folder, output_folder)
# Out:
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\dog_bark\100032-3-0-0.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\dog_bark\dog_bark\100032-3-0-0.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\dog_bark\100652-3-0-0.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\dog_bark\dog_bark\100652-3-0-0.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\dog_bark\100652-3-0-1.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\dog_bark\dog_bark\100652-3-0-1.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\dog_bark\100652-3-0-2.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\dog_bark\dog_bark\100652-3-0-2.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\dog_bark\100652-3-0-3.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\dog_bark\dog_bark\100652-3-0-3.png
# ...

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def create_spectrogram(wav_file, output_path):
    y, sr = librosa.load(wav_file)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    S_dB = librosa.power_to_db(S, ref=np.max)
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_dB, sr=sr)
    plt.colorbar(format='%+2.0f dB')
    # plt.title('Mel-frequency spectrogram')
    plt.tight_layout()
    
    plt.savefig(output_path)
    plt.close()

def process_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for subdir, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.wav'):
                class_name = os.path.basename(subdir)
                output_subfolder = os.path.join(output_folder, class_name)
                if not os.path.exists(output_subfolder):
                    os.makedirs(output_subfolder)
                
                wav_file = os.path.join(subdir, file)
                output_path = os.path.join(output_subfolder, os.path.splitext(file)[0] + '.png')
                create_spectrogram(wav_file, output_path)
                print(f"Processed {wav_file} to {output_path}")

input_folder = "C:\\Users\\darsh\\Deep_Learning\\Datset_of_csv\\drilling"
output_folder = "C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class\\drilling"
process_folder(input_folder, output_folder)
# Out:
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\drilling\103199-4-0-0.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\drilling\drilling\103199-4-0-0.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\drilling\103199-4-0-3.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\drilling\drilling\103199-4-0-3.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\drilling\103199-4-0-4.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\drilling\drilling\103199-4-0-4.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\drilling\103199-4-0-5.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\drilling\drilling\103199-4-0-5.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\drilling\103199-4-0-6.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\drilling\drilling\103199-4-0-6.png
# ...

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def create_spectrogram(wav_file, output_path):
    y, sr = librosa.load(wav_file)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    S_dB = librosa.power_to_db(S, ref=np.max)
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_dB, sr=sr)
    plt.colorbar(format='%+2.0f dB')
    # plt.title('Mel-frequency spectrogram')
    plt.tight_layout()
    
    plt.savefig(output_path)
    plt.close()

def process_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for subdir, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.wav'):
                class_name = os.path.basename(subdir)
                output_subfolder = os.path.join(output_folder, class_name)
                if not os.path.exists(output_subfolder):
                    os.makedirs(output_subfolder)
                
                wav_file = os.path.join(subdir, file)
                output_path = os.path.join(output_subfolder, os.path.splitext(file)[0] + '.png')
                create_spectrogram(wav_file, output_path)
                print(f"Processed {wav_file} to {output_path}")

input_folder = "C:\\Users\\darsh\\Deep_Learning\\Datset_of_csv\\engine_idling"
output_folder = "C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class\\engine_idling"
process_folder(input_folder, output_folder)
# Out:
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\engine_idling\102857-5-0-0.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\engine_idling\engine_idling\102857-5-0-0.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\engine_idling\102857-5-0-1.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\engine_idling\engine_idling\102857-5-0-1.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\engine_idling\102857-5-0-10.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\engine_idling\engine_idling\102857-5-0-10.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\engine_idling\102857-5-0-11.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\engine_idling\engine_idling\102857-5-0-11.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\engine_idling\102857-5-0-12.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\engine_idling\engine_idling\102857-5-0-12.png
# ...

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def create_spectrogram(wav_file, output_path):
    y, sr = librosa.load(wav_file)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    S_dB = librosa.power_to_db(S, ref=np.max)
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_dB, sr=sr)
    plt.colorbar(format='%+2.0f dB')
    # plt.title('Mel-frequency spectrogram')
    plt.tight_layout()
    
    plt.savefig(output_path)
    plt.close()

def process_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for subdir, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.wav'):
                class_name = os.path.basename(subdir)
                output_subfolder = os.path.join(output_folder, class_name)
                if not os.path.exists(output_subfolder):
                    os.makedirs(output_subfolder)
                
                wav_file = os.path.join(subdir, file)
                output_path = os.path.join(output_subfolder, os.path.splitext(file)[0] + '.png')
                create_spectrogram(wav_file, output_path)
                print(f"Processed {wav_file} to {output_path}")

input_folder = "C:\\Users\\darsh\\Deep_Learning\\Datset_of_csv\\gun_shot"
output_folder = "C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class\\gun_shot"
process_folder(input_folder, output_folder)
# Out:
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\gun_shot\102305-6-0-0.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\gun_shot\gun_shot\102305-6-0-0.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\gun_shot\106955-6-0-0.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\gun_shot\gun_shot\106955-6-0-0.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\gun_shot\110622-6-0-0.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\gun_shot\gun_shot\110622-6-0-0.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\gun_shot\111048-6-0-0.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\gun_shot\gun_shot\111048-6-0-0.png
# Processed C:\Users\darsh\Deep_Learning\Datset_of_csv\gun_shot\122690-6-0-0.wav to C:\Users\darsh\Deep_Learning\Imagee_Datasets_after_class\gun_shot\gun_shot\122690-6-0-0.png
# ...

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def create_spectrogram(wav_file, output_path):
    y, sr = librosa.load(wav_file)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    S_dB = librosa.power_to_db(S, ref=np.max)
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_dB, sr=sr)
    plt.colorbar(format='%+2.0f dB')
    # plt.title('Mel-frequency spectrogram')
    plt.tight_layout()
    
    plt.savefig(output_path)
    plt.close()

def process_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for subdir, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.wav'):
                class_name = os.path.basename(subdir)
                output_subfolder = os.path.join(output_folder, class_name)
                if not os.path.exists(output_subfolder):
                    os.makedirs(output_subfolder)
                
                wav_file = os.path.join(subdir, file)
                output_path = os.path.join(output_subfolder, os.path.splitext(file)[0] + '.png')
                create_spectrogram(wav_file, output_path)
                print(f"Processed {wav_file} to {output_path}")

input_folder = "C:\\Users\\darsh\\Deep_Learning\\Datset_of_csv\\jackhammer"
output_folder = "C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class\\jackhammer"
process_folder(input_folder, output_folder)

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def create_spectrogram(wav_file, output_path):
    y, sr = librosa.load(wav_file)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    S_dB = librosa.power_to_db(S, ref=np.max)
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_dB, sr=sr)
    plt.colorbar(format='%+2.0f dB')
    # plt.title('Mel-frequency spectrogram')
    plt.tight_layout()
    
    plt.savefig(output_path)
    plt.close()

def process_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for subdir, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.wav'):
                class_name = os.path.basename(subdir)
                output_subfolder = os.path.join(output_folder, class_name)
                if not os.path.exists(output_subfolder):
                    os.makedirs(output_subfolder)
                
                wav_file = os.path.join(subdir, file)
                output_path = os.path.join(output_subfolder, os.path.splitext(file)[0] + '.png')
                create_spectrogram(wav_file, output_path)
                print(f"Processed {wav_file} to {output_path}")

input_folder = "C:\\Users\\darsh\\Deep_Learning\\Datset_of_csv\\siren"
output_folder = "C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class\\siren"
process_folder(input_folder, output_folder)

# %%
import os
import librosa
import librosa.display
import matplotlib.pyplot as plt
import numpy as np

def create_spectrogram(wav_file, output_path):
    y, sr = librosa.load(wav_file)
    S = librosa.feature.melspectrogram(y=y, sr=sr)
    S_dB = librosa.power_to_db(S, ref=np.max)
    
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(S_dB, sr=sr)
    plt.colorbar(format='%+2.0f dB')
    # plt.title('Mel-frequency spectrogram')
    plt.tight_layout()
    
    plt.savefig(output_path)
    plt.close()

def process_folder(input_folder, output_folder):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    for subdir, _, files in os.walk(input_folder):
        for file in files:
            if file.endswith('.wav'):
                class_name = os.path.basename(subdir)
                output_subfolder = os.path.join(output_folder, class_name)
                if not os.path.exists(output_subfolder):
                    os.makedirs(output_subfolder)
                
                wav_file = os.path.join(subdir, file)
                output_path = os.path.join(output_subfolder, os.path.splitext(file)[0] + '.png')
                create_spectrogram(wav_file, output_path)
                print(f"Processed {wav_file} to {output_path}")

input_folder = "C:\\Users\\darsh\\Deep_Learning\\Datset_of_csv\\street_music"
output_folder = "C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class\\street_music"
process_folder(input_folder, output_folder)

# %%
import os
import random
import shutil

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def split_dataset(class_folders, output_dir, train_ratio=0.8, validation_ratio=0.1, test_ratio=0.1, num_images_per_class=200):
    for class_folder in class_folders:
        class_name = os.path.basename(class_folder)
        all_images = os.listdir(class_folder)
        selected_images = random.sample(all_images, num_images_per_class)

        num_train = int(train_ratio * num_images_per_class)
        num_validation = int(validation_ratio * num_images_per_class)
        num_test = num_images_per_class - num_train - num_validation

        train_images = selected_images[:num_train]
        validation_images = selected_images[num_train:num_train + num_validation]
        test_images = selected_images[num_train + num_validation:]

        # Create directories for each class
        create_dir(os.path.join(output_dir, 'train', class_name))
        create_dir(os.path.join(output_dir, 'validation', class_name))
        create_dir(os.path.join(output_dir, 'test', class_name))

        # Copy images to corresponding directories
        for img in train_images:
            shutil.copy(os.path.join(class_folder, img), os.path.join(output_dir, 'train', class_name, img))
        
        for img in validation_images:
            shutil.copy(os.path.join(class_folder, img), os.path.join(output_dir, 'validation', class_name, img))
        
        for img in test_images:
            shutil.copy(os.path.join(class_folder, img), os.path.join(output_dir, 'test', class_name, img))

# Example usage
dataset_dir = 'C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class'
output_dir = 'C:\\Users\\darsh\\Deep_Learning\\Output-1'

class_folders = [os.path.join(dataset_dir, class_name) for class_name in os.listdir(dataset_dir)]
split_dataset(class_folders, output_dir)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 43
#      40 output_dir = 'C:\\Users\\darsh\\Deep_Learning\\Output-1'
#      42 class_folders = [os.path.join(dataset_dir, class_name) for class_name in os.listdir(dataset_dir)]
# ---> 43 split_dataset(class_folders, output_dir)
#
# Cell In[17], line 13, in split_dataset(class_folders, output_dir, train_ratio, validation_ratio, test_ratio, num_images_per_class)
#      11 class_name = os.path.basename(class_folder)
#      12 all_images = os.listdir(class_folder)
# ---> 13 selected_images = random.sample(all_images, num_images_per_class)
#      15 num_train = int(train_ratio * num_images_per_class)
#      16 num_validation = int(validation_ratio * num_images_per_class)
#
# File ~\miniconda3\envs\tf\lib\random.py:449, in Random.sample(self, population, k, counts)
#     447 randbelow = self._randbelow
# ...

# %%
import os
import random
import shutil

def create_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)

def split_dataset(class_folders, output_dir, train_ratio=0.8, validation_ratio=0.1, test_ratio=0.1):
    for class_folder in class_folders:
        class_name = os.path.basename(class_folder)
        all_images = os.listdir(class_folder)
        random.shuffle(all_images)  # Shuffle images to ensure random selection

        num_images = len(all_images)
        num_train = int(train_ratio * num_images)
        num_validation = int(validation_ratio * num_images)
        num_test = num_images - num_train - num_validation

        train_images = all_images[:num_train]
        validation_images = all_images[num_train:num_train + num_validation]
        test_images = all_images[num_train + num_validation:]

        # Create directories for each class
        create_dir(os.path.join(output_dir, 'train', class_name))
        create_dir(os.path.join(output_dir, 'validation', class_name))
        create_dir(os.path.join(output_dir, 'test', class_name))

        # Copy images to corresponding directories
        for img in train_images:
            shutil.copy(os.path.join(class_folder, img), os.path.join(output_dir, 'train', class_name, img))
        
        for img in validation_images:
            shutil.copy(os.path.join(class_folder, img), os.path.join(output_dir, 'validation', class_name, img))
        
        for img in test_images:
            shutil.copy(os.path.join(class_folder, img), os.path.join(output_dir, 'test', class_name, img))

# Example usage
dataset_dir = 'C:\\Users\\darsh\\Deep_Learning\\Imagee_Datasets_after_class'
output_dir = 'C:\\Users\\darsh\\Deep_Learning\\Output-1'

# Get class folders
class_folders = [os.path.join(dataset_dir, class_name) for class_name in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, class_name))]
split_dataset(class_folders, output_dir)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[18], line 45
#      43 # Get class folders
#      44 class_folders = [os.path.join(dataset_dir, class_name) for class_name in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, class_name))]
# ---> 45 split_dataset(class_folders, output_dir)
#
# Cell In[18], line 37, in split_dataset(class_folders, output_dir, train_ratio, validation_ratio, test_ratio)
#      34     shutil.copy(os.path.join(class_folder, img), os.path.join(output_dir, 'validation', class_name, img))
#      36 for img in test_images:
# ---> 37     shutil.copy(os.path.join(class_folder, img), os.path.join(output_dir, 'test', class_name, img))
#
# File ~\miniconda3\envs\tf\lib\shutil.py:427, in copy(src, dst, follow_symlinks)
#     425 if os.path.isdir(dst):
#     426     dst = os.path.join(dst, os.path.basename(src))
# ...

# %%
import os
import shutil
import random
from math import floor

# Define paths
dataset_path =  "C:/Users/darsh/Deep_Learning/Wave Classifiaction/Final Datasets" # Path to the dataset with 10 class folders
train_path = "C:/Users/darsh/Deep_Learning/Wave Classifiaction/Output/train"
test_path = "C:/Users/darsh/Deep_Learning/Wave Classifiaction/Output/test"
val_path = "C:/Users/darsh/Deep_Learning/Wave Classifiaction/Output/val"

# Create train, test, val directories with subdirectories for each class
for category in os.listdir(dataset_path):
    os.makedirs(os.path.join(train_path, category), exist_ok=True)
    os.makedirs(os.path.join(test_path, category), exist_ok=True)
    os.makedirs(os.path.join(val_path, category), exist_ok=True)

# Split ratios
train_ratio = 0.8
test_ratio = 0.1
val_ratio = 0.1

# Function to split and move files
def split_data(category, files):
    random.shuffle(files)
    num_train = floor(len(files) * train_ratio)
    num_test = floor(len(files) * test_ratio)
    num_val = len(files) - num_train - num_test  # Ensure all files are accounted for

    train_files = files[:num_train]
    test_files = files[num_train:num_train + num_test]
    val_files = files[num_train + num_test:]

    for file in train_files:
        shutil.move(os.path.join(dataset_path, category, file), os.path.join(train_path, category, file))
    for file in test_files:
        shutil.move(os.path.join(dataset_path, category, file), os.path.join(test_path, category, file))
    for file in val_files:
        shutil.move(os.path.join(dataset_path, category, file), os.path.join(val_path, category, file))

# Split each class
for category in os.listdir(dataset_path):
    files = os.listdir(os.path.join(dataset_path, category))
    split_data(category, files)

print("Dataset split into train, test, and val folders successfully.")
# Out:
# Dataset split into train, test, and val folders successfully.
